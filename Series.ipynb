# %%
import pandas as pd
import numpy as np
data = pd.read_csv('matches.csv')
data.sample(7)
# Out:
#       id  season          city        date                    team1  \
# 172  173    2009  Johannesburg  2009-05-23      Chennai Super Kings
# 585  586    2016    Chandigarh  2016-04-17  Rising Pune Supergiants
# 520  521    2015       Chennai  2015-04-11      Chennai Super Kings
# 444  445    2013        Ranchi  2013-05-15            Pune Warriors
# 111  112    2008       Kolkata  2008-05-25          Kings XI Punjab
# 380  381    2012       Chennai  2012-05-27      Chennai Super Kings
# 526  527    2015       Kolkata  2015-04-30      Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# 172  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 585              Kings XI Punjab      Rising Pune Supergiants           bat
# 520          Sunrisers Hyderabad          Chennai Super Kings           bat
# 444        Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %%
myseries = data['winner'].value_counts()
myseries
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
print(myseries.values)
print(myseries.index)
# Out:
# [92 79 77 73 70 63 62 42 29 13 12 10  6  5]
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Gujarat Lions', 'Pune Warriors', 'Rising Pune Supergiant',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype='object', name='winner')

# %%
print(myseries.head())
print(myseries.tail())
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Name: count, dtype: int64
# winner
# Gujarat Lions              13
# Pune Warriors              12
# Rising Pune Supergiant     10
# Kochi Tuskers Kerala        6
# Rising Pune Supergiants     5
# Name: count, dtype: int64

# %%
# If the indexing of the series is same then we can perform mathmatical operations on the series
# If we want to calculate total number of matches played by each team
myseries2 = data['team1'].value_counts() + data['team2'].value_counts()
myseries2
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# Name: count, dtype: int64

# %%
total_matches = myseries2.sort_values() # Assending order
print(total_matches)
# Out:
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Rising Pune Supergiant          16
# Gujarat Lions                   30
# Pune Warriors                   46
# Deccan Chargers                 75
# Sunrisers Hyderabad             76
# Rajasthan Royals               118
# Chennai Super Kings            131
# Delhi Daredevils               147
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Royal Challengers Bangalore    152
# Mumbai Indians                 157
# Name: count, dtype: int64

# %%
total_matches1 = myseries2.sort_values(ascending=False) # Dessending order
print(total_matches1)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
total_teams= total_matches[total_matches>100]
print(total_teams) # Teams that played more than 100 matches
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Name: count, dtype: int64

# %%
# If we want to calculate the percentage of matches won by each team
total_matches = myseries2.sort_values(ascending=False)
total_wins = myseries.sort_values(ascending=False)  
percentage_wins = ((total_wins / total_matches) * 100).round(2).sort_values(ascending=False)
print(percentage_wins)
# Out:
# Rising Pune Supergiant         62.50
# Chennai Super Kings            60.31
# Mumbai Indians                 58.60
# Sunrisers Hyderabad            55.26
# Rajasthan Royals               53.39
# Kolkata Knight Riders          52.03
# Royal Challengers Bangalore    48.03
# Kings XI Punjab                47.30
# Gujarat Lions                  43.33
# Kochi Tuskers Kerala           42.86
# Delhi Daredevils               42.18
# Deccan Chargers                38.67
# Rising Pune Supergiants        35.71
# Pune Warriors                  26.09
# Name: count, dtype: float64

# %%
# drop_duplicates : remove all the duplicate rows based on a column
data.drop_duplicates(subset=['city']).shape # inplace= True will modify the original dataframe
# keep : first, last, False
# keep='last' will keep the last occurrence of the duplicate row  
# keep=False will remove all the duplicate rows not even one row will be kept
# Out:
# (31, 18)

# %%
# Eg : # If we want to find the winner team of each year, logic is to keep the last occurrence of the duplicate season column
data.drop_duplicates(subset=['season'], keep='last')[['season', 'winner']].sort_values(by='season', ascending=True).reset_index(drop=True)
# Out:
#    season                 winner
# 0    2008       Rajasthan Royals
# 1    2009        Deccan Chargers
# 2    2010    Chennai Super Kings
# 3    2011    Chennai Super Kings
# 4    2012  Kolkata Knight Riders
# 5    2013         Mumbai Indians
# 6    2014  Kolkata Knight Riders
# 7    2015         Mumbai Indians
# 8    2016    Sunrisers Hyderabad
# 9    2017         Mumbai Indians

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...
